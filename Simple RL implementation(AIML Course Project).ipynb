# %%
import random
from typing import List


class Environment:
    def __init__(self):
        self.steps_left = 20

    def get_observation(self) -> List[float]:
        return [0.0, 0.0, 0.0]

    def get_actions(self) -> List[int]:
        return [0, 1]

    def is_done(self) -> bool:
        return self.steps_left == 0

    def action(self, action: int) -> float:
        if self.is_done():
            raise Exception("Game is over")
        self.steps_left -= 1
        return random.random()

# %%
class Agent:
    def __init__(self):
        self.total_reward = 0.0

    def step(self, env: Environment):
        current_obs = env.get_observation()
        print("Observations {}".format(current_obs))
        actions = env.get_actions()
        print(actions)
        reward = env.action(random.choice(actions))
        self.total_reward += reward
        print("Total Reward {}".format(self.total_reward))

# %%
if __name__ == "__main__":
    env = Environment()
    agent = Agent()
    i=0

    while not env.is_done():
        i=i+1
        print("Step {}".format(i))
        agent.step(env)

    print("Total reward received: %.4f" % agent.total_reward)
# Out:
# Step 1
# Observations [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 0.4441147403951309
# Step 2
# Observations [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 1.3868331134773202
# Step 3
# Observations [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 1.536624851914151
# Step 4
# Observations [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 1.902013863937909
# Step 5
# Observations [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 1.9325442025382435
# Step 6
# Observations [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 2.3146265272451565
# Step 7
# Observations [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 2.545475657187327
# Step 8
# Observations [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 3.1743758465987133
# Step 9
# Observations [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 3.6139423344611217
# Step 10
# Observations [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 4.277683896930396
# Step 11
# Observations [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 5.212382733857876
# Step 12
# Observations [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 5.35411299911531
# Step 13
# Observations [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 6.1753117867324985
# Step 14
# Observations [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 6.828046795046561
# Step 15
# Observations [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 7.117103963537936
# Step 16
# Observations [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 7.286755159830498
# Step 17
# Observations [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 7.639047628207108
# Step 18
# Observations [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 8.354250723976481
# Step 19
# Observations [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 8.988319319627108
# Step 20
# Observations [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 9.942635231140791
# Total reward received: 9.9426
